# %%
import pandas as pd
apc = pd.read_csv("apc_output.csv")

# %%
route5= apc[apc.ROUTE_ABBR ==5]
route5
# Out:
#        Unnamed: 0  Unnamed: 0.1          ARRIVAL_DTM        DEPARTURE_DTM  \
# 30             30       6639274  2018-04-07 05:11:00  2018-04-07 05:21:00
# 125           125       6639275  2018-04-07 05:30:00  2018-04-07 05:30:00
# 143           143       6639276  2018-04-07 05:31:00  2018-04-07 05:32:00
# 159           159       6664827  2018-04-07 05:33:00  2018-04-07 05:36:00
# 160           160       6639277  2018-04-07 05:33:00  2018-04-07 05:33:00
# ...           ...           ...                  ...                  ...
# 54466       54466       6671431  2018-04-08 01:58:00  2018-04-08 01:58:00
# 54469       54469       6671432  2018-04-08 02:01:00  2018-04-08 02:01:00
# 54471       54471       6671433  2018-04-08 02:02:00  2018-04-08 02:02:00
# 54472       54472       6671434  2018-04-08 02:03:00  2018-04-08 02:04:00
# 54473       54473       6671435  2018-04-08 02:04:00  2018-04-08 02:04:00
#
#        ROUTE_ABBR                     ROUTE_NAME  VECHILE_TAG   LATITUDE  \
# ...

# %%
gtfs_folder = "MARTA_gtfs_03_14_2018"
from os.path import join

# %%
stops = pd.read_csv(join(gtfs_folder, "stops.txt"))
stop_times = pd.read_csv(join(gtfs_folder, "stop_times.txt"))
trips = pd.read_csv(join(gtfs_folder, "trips.txt"))
routes = pd.read_csv(join(gtfs_folder, "routes.txt"))

# %%
route_id = routes[routes.route_short_name == "5"].route_id.values[0]
route_id
# Out:
# 7638

# %%
# trip_ids for a given route
trip_ids = trips[(trips.route_id == route_id) & (trips.service_id == 3)].trip_id.values

# %%
stop_times[stop_times.trip_id.isin(trip_ids)].sort_values("departure_time")
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence
# 143808  6032241     05:15:00       05:15:00   903009              1
# 143809  6032241     05:17:31       05:17:31   902999              2
# 143810  6032241     05:18:00       05:18:00   902704              3
# 143811  6032241     05:19:05       05:19:05   903033              4
# 143812  6032241     05:20:00       05:20:00   902868              5
# ...         ...          ...            ...      ...            ...
# 621291  6056855     26:11:56       26:11:56   902816             53
# 621292  6056855     26:13:05       26:13:05   902888             54
# 621293  6056855     26:13:30       26:13:30   211926             55
# 621294  6056855     26:14:18       26:14:18   903000             56
# 621295  6056855     26:15:00       26:15:00   903009             57
#
# [6667 rows x 5 columns]
