# %%
pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from folium) (1.16.4)
# Requirement already satisfied: jinja2>=2.9 in c:\anaconda\lib\site-packages (from folium) (2.10.1)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/81/6d/31c83485189a2521a75b4130f1fee5364f772a0375f81afff619004e5237/branca-0.4.0-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\anaconda\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in c:\anaconda\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.0 folium-0.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd

#read in the Google Sheets called route5_on_time_performance
data = pd.read_csv("route5_on_time_performance.csv")
#Goal: for every row, make a tuple of (latitude, longitude) + other details --> giant list of info per stop

other_coordinate_info = []
for index, row in data.iterrows(): 
    tuples = (row['stop_lat'], row['stop_lon'])
    stop = [tuples, row['stop_id'], row['number_of_times'], row['average_on_time_performance_seconds'], row['stop_name']]
    other_coordinate_info.append(stop)
    
#other_coordinate_info contain: (lat, long), stop_id, number of times, average on-time, stop_name

# %%
other_coordinate_info
# Out:
# [[(33.922703000000006, -84.37921800000001),
#   902700,
#   28,
#   86.0,
#   'ROSWELL RD NE @ HILDERBRAND DR'],
#  [(33.918641, -84.379085),
#   902751,
#   22,
#   133.63636359999998,
#   'ROSWELL RD NE @ HAMMOND DR NE'],
#  [(33.909002, -84.378784),
#   902699,
#   41,
#   187.0487805,
#   'ROSWELL RD NE @ LAKE PLACID DR NE'],
#  [(33.900208, -84.380478), 905744, 12, 196.0, 'ROSWELL RD NE @ MARYEANNA DR'],
#  [(33.883138, -84.380128),
#   905746,
#   26,
#   141.4615385,
#   'ROSWELL RD NE@MYSTIC PL NE'],
#  [(33.853317, -84.381663),
#   905928,
#   29,
#   197.51724140000002,
#   'PIEDMONT RD NE @ HABERSHAM RD NE'],
#  [(33.844398999999996, -84.37180699999999),
#   905526,
#   26,
#   235.3846154,
#   'PIEDMONT RD NE @ PEACHTREE RD NE'],
#  [(33.839531, -84.369377),
#   900481,
#   13,
#   154.0,
#   'PIEDMONT RD NE @ E PACES FERRY RD NE'],
#  [(33.837061, -84.368146),
#   900482,
#   24,
#   147.875,
#   'PIEDMONT RD NE @ PHARR RD NE'],
#  [(33.823071999999996, -84.36995),
#   902145,
#   57,
#   690.5263158,
#   'LINDBERGH CENTER STATION - NORTH LOOP/MOROSGO DR'],
#  [(33.835906, -84.36792700000001),
#   900480,
#   11,
#   -121.7272727,
#   'PIEDMONT RD NE @ BURKE RD NE'],
#  [(33.837499, -84.368222),
#   901702,
#   24,
#   -71.0,
#   'PIEDMONT RD NE @ PEACHTREE DR NE'],
#  [(33.844583, -84.371608),
#   905429,
#   34,
#   22.94117647,
#   'PIEDMONT RD NE @ PEACHTREE RD NE'],
#  [(33.846081, -84.372483),
#   905289,
#   30,
#   62.2,
#   'PIEDMONT RD NE @ TOWER PLACE DR'],
#  [(33.860558000000005, -84.380416),
#   905528,
#   15,
#   118.0,
#   'ROSWELL RD NE @ SHELDON DR NE'],
#  [(33.872971, -84.38096999999999),
#   905577,
#   24,
#   39.66666667,
#   'ROSWELL RD NE @ MIDVALE DR NE'],
#  [(33.879245000000004, -84.379733),
#   905627,
#   23,
#   288.9565217,
#   'ROSWELL RD NE @ WINDSOR PKWY NE'],
#  [(33.88297, -84.37994),
#   905629,
#   29,
#   59.96551724,
#   'ROSWELL RD NE@MYSTIC PL NE'],
#  [(33.887039, -84.381622),
#   905871,
#   19,
#   7.157894737,
#   'ROSWELL RD NE @ LONG ISLAND DR NE'],
#  [(33.90044, -84.38), 905991, 15, -15.0, 'ROSWELL RD NE@GREEN HILL RD NE'],
#  [(33.924369, -84.377367), 906362, 24, 104.0, 'MT VERNON HWY@BOYLSTON DR'],
#  [(33.920108, -84.379042),
#   906334,
#   22,
#   96.31818182,
#   'ROSWELL RD NE @ SANDY SPRINGS PL'],
#  [(33.907231, -84.378718), 902698, 27, 206.4444444, 'ROSWELL RD NE @ 5531'],
#  [(33.887263, -84.381677),
#   905863,
#   20,
#   279.0,
#   'ROSWELL RD NE @ LONG ISLAND DR NE'],
#  [(33.825981, -84.367215),
#   901756,
#   24,
#   11.25,
#   'PIEDMONT RD NE @ SIDNEY MARCUS BLVD NE'],
#  [(33.849614, -84.377089), 905408, 4, 249.0, 'PIEDMONT RD NE @ 3500'],
#  [(33.890188, -84.381275),
#   905988,
#   32,
#   45.5,
#   'ROSWELL RD NE @ BELLE ISLE RD NE'],
#  [(33.905396, -84.378695), 902697, 1, -446.0, 'ROSWELL RD NE @ 5491'],
#  [(33.914017, -84.379242),
#   906292,
#   22,
#   247.63636359999998,
#   'ROSWELL RD NE @ ALLEN RD NE'],
#  [(33.833553, -84.367959),
#   900479,
#   1,
#   -20.0,
#   'PIEDMONT RD NE @ ELLIOTT CIR NE'],
#  [(33.841803999999996, -84.37039),
#   901704,
#   16,
#   -62.4375,
#   'PIEDMONT RD NE @ MARTINA DR NE'],
#  [(33.852924, -84.38105300000001),
#   905524,
#   25,
#   89.36,
#   'PIEDMONT RD NE @ HABERSHAM RD NE'],
#  [(33.855554, -84.382579),
#   905927,
#   23,
#   102.9130435,
#   'ROSWELL RD NE @ POWERS FERRY RD NW'],
#  [(33.915285, -84.379235),
#   906293,
#   19,
#   62.05263158,
#   'ROSWELL RD NE @ CARPENTER DR NE'],
#  [(33.918831, -84.378862), 906308, 24, 82.5, 'ROSWELL RD NE@HAMMOND DR NE'],
#  [(33.923119, -84.370666),
#   906333,
#   3,
#   58.33333333,
#   'JOHNSON FERRY RD@KAYRON DR'],
#  [(33.846509999999995, -84.372831),
#   905410,
#   28,
#   319.85714289999993,
#   'PIEDMONT RD NE @ TOWER PLACE DR NE'],
#  [(33.838752, -84.368854),
#   901703,
#   19,
#   -43.52631579,
#   'PIEDMONT RD NE @ E PACES FERRY RD NE'],
#  [(33.907636, -84.37867299999999),
#   906306,
#   26,
#   -29.03846154,
#   'ROSWELL RD NE @ 5555'],
#  [(33.909521999999996, -84.378654),
#   906290,
#   37,
#   15.13513514,
#   'ROSWELL RD NE @ LAKE PLACID DR NE'],
#  [(33.917522, -84.379041), 906307, 19, 34.84210526, 'ROSWELL RD NE @ 5925'],
#  [(33.92001, -84.37894399999999),
#   906309,
#   26,
#   87.0,
#   'ROSWELL RD NE @ SANDY SPRINGS PL NE'],
#  [(33.92371, -84.37488), 902662, 5, -68.0, 'JOHNSON FERRY RD@HARLESTON RD'],
#  [(33.901628, -84.37916), 902747, 5, 154.0, 'ROSWELL RD NE@GLENRIDGE DR NE'],
#  [(33.861167, -84.38045), 905646, 15, 98.0, 'ROSWELL RD NE @ LE BRUN RD NE'],
#  [(33.857882000000004, -84.38148100000001),
#   906001,
#   22,
#   87.45454545,
#   'ROSWELL RD NE @ IVY PKWY NE'],
#  [(33.851152, -84.37937600000001),
#   905760,
#   9,
#   373.6666667,
#   'PIEDMONT RD NE @ 3558'],
#  [(33.827009999999994, -84.367019),
#   900477,
#   22,
#   72.72727273,
#   'PIEDMONT RD NE @ MIAMI CIR NE'],
#  [(33.831619, -84.368001), 901757, 2, 36.0, 'PIEDMONT RD NE @ DARLINGTON RD'],
#  [(33.902783, -84.378606), 902696, 5, 29.0, 'ROSWELL RD NE @ GLENRIDGE DR NE'],
#  [(33.916242, -84.37923599999999),
#   906361,
#   15,
#   158.0,
#   'ROSWELL RD NE @ CLIFTWOOD DR NE'],
#  [(33.890163, -84.381524),
#   905864,
#   23,
#   162.6521739,
#   'ROSWELL RD NE@W BELLE ISLE RD NE'],
#  [(33.875271000000005, -84.380612),
#   905578,
#   17,
#   206.8823529,
#   'ROSWELL RD NE @ WIEUCA RD NE'],
#  [(33.877285, -84.379764),
#   905579,
#   14,
#   100.1428571,
#   'ROSWELL RD NE @ DILBECK PL NW'],
#  [(33.85092, -84.378984), 905523, 7, 64.71428571, 'PIEDMONT RD NE @ 3565'],
#  [(33.84171, -84.37053), 901705, 10, 250.2, 'PIEDMONT RD NE @ MARTINA DR NE'],
#  [(33.920969, -84.344734), 903009, 49, 971.0204082, 'DUNWOODY STATION'],
#  [(33.918960999999996, -84.351952),
#   902704,
#   20,
#   131.25,
#   'HAMMOND DR @ PEACHTREE DUNWOODY RD'],
#  [(33.919113, -84.360336), 902868, 10, 84.0, 'HAMMOND DR NE @ BARFIELD RD NE'],
#  [(33.873007, -84.381089), 905580, 15, 192.0, 'ROSWELL RD NE @ MIDVALE DR NE'],
#  [(33.857521000000006, -84.381584),
#   906000,
#   15,
#   115.46666670000002,
#   'ROSWELL RD NE @ IVY PKWY NE'],
#  [(33.9189, -84.354671),
#   902816,
#   11,
#   -3.8181818180000002,
#   'HAMMOND DR NE @ 1005'],
#  [(33.918901, -84.349888), 902999, 5, 31.6, 'HAMMOND DR NE @ 1150'],
#  [(33.919057, -84.363941), 903199, 5, 81.0, 'HAMMOND DR@GLENRIDGE DR'],
#  [(33.924741, -84.37824499999999),
#   903158,
#   2,
#   72.0,
#   'JOHNSON FERRY RD NE @ ROSWELL RD'],
#  [(33.870358, -84.381109),
#   905644,
#   11,
#   185.5454545,
#   'ROSWELL RD NE @ RICKENBACKER DR NE'],
#  [(33.870188, -84.380989),
#   905529,
#   11,
#   120.0909091,
#   'ROSWELL RD NE @ RICKENBACKER DR NE'],
#  [(33.905167, -84.378537), 906335, 10, 57.0, 'ROSWELL RD NE @ 5491'],
#  [(33.828013, -84.367303), 901755, 2, -126.0, 'PIEDMONT RD NE @ MIAMI CIR NE'],
#  [(33.922714, -84.379102),
#   906294,
#   15,
#   91.86666667,
#   'ROSWELL RD NE @ HILDERBRAND DR NE'],
#  [(33.918943, -84.360434),
#   903010,
#   11,
#   -18.54545455,
#   'HAMMOND DR NE @ BARFIELD RD'],
#  [(33.864746000000004, -84.38075699999999),
#   905762,
#   3,
#   283.0,
#   'ROSWELL RD NE @ LAKEMOORE DR'],
#  [(33.918924, -84.36326700000001),
#   902665,
#   1,
#   154.0,
#   'HAMMOND DR NE @ GLENRIDGE DR NE'],
#  [(33.918973, -84.348156), 211926, 1, -85.0, 'HAMMOND DR @ 1145'],
#  [(33.848452, -84.37418199999999),
#   905409,
#   6,
#   188.0,
#   'PIEDMONT RD NE @ CARSON LN NE'],
#  [(33.829409000000005, -84.367652),
#   900478,
#   1,
#   41.0,
#   'PIEDMONT RD NE @ ALPINE RD NE'],
#  [(33.865024, -84.380746), 905412, 2, 62.0, 'ROSWELL RD NE @ LAKEMOORE DR NE'],
#  [(33.895022, -84.381388), 905814, 2, 223.0, 'ROSWELL RD NE @ OSNER DR NE'],
#  [(33.867548, -84.38103100000001),
#   905413,
#   2,
#   163.0,
#   'ROSWELL RD NE @ CHASTAIN DR NE'],
#  [(33.862831, -84.380189),
#   905411,
#   2,
#   247.0,
#   'ROSWELL RD NE @ LAND O LAKES DR NE'],
#  [(33.922431, -84.367997),
#   902746,
#   1,
#   105.0,
#   'JOHNSON FERRY RD NE @ GLENRIDGE DR NE'],
#  [(33.894978, -84.38126899999999), 210802, 2, 250.0, 'ROSWELL RD@OSNER DR'],
#  [(33.879156, -84.379852),
#   905812,
#   2,
#   150.0,
#   'ROSWELL RD NE @ WINDSOR PKWY NE'],
#  [(33.923038, -84.370644), 906363, 1, -119.0, 'JOHNSON FERRY RD@KAYRON DR'],
#  [(33.884946, -84.380978), 905870, 1, 267.0, 'ROSWELL RD NE@MYSTIC CT'],
#  [(33.902489, -84.378456), 906305, 2, 96.0, 'ROSWELL RD NE @ GLENRIDGE DR NE']]

# %%
#Create a base map using coordinates of Atlanta
m = folium.Map(location=[33.7490, -84.3880])

#add markers
for stop in other_coordinate_info:
    info = 'stop_id: {}, num_of_times: {}, avg_ontime_seconds: {}, stop_name: {}'.format(stop[1], stop[2], stop[3], stop[4])
    if stop[3] > 600:
        folium.Marker(stop[0], popup = info, icon=folium.Icon(color='black')).add_to(m)
    if ((stop[3] < 600) & (stop[3] >= 300)):
        folium.Marker(stop[0], popup = info, icon=folium.Icon(color='red')).add_to(m)
    if ((stop[3] < 300) & (stop[3] >= 0)): 
        folium.Marker(stop[0], popup = info, icon=folium.Icon(color='white')).add_to(m)
    if ((stop[3] > -300) & (stop[3] < 0)): 
        folium.Marker(stop[0], popup = info, icon=folium.Icon(color='blue')).add_to(m)
    if ((stop[3] > -600) & (stop[3] < -300)): 
        folium.Marker(stop[0], popup = info, icon=folium.Icon(color='orange')).add_to(m)
    
#add lines
#folium.PolyLine(coordinates, color="red", weight=2.5, opacity=1).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
